# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn-whitegrid")
import numpy as np

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0,10,1000)
ax.plot(x, np.sin(x))

# %%
# Различные цвета, которые поддерживает данная библиотека
plt.plot(x, np.sin(x - 0), color='blue')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g')           # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
plt.plot(x, x+0, linestyle='-')
plt.plot(x, x+1, linestyle='--')
plt.plot(x, x+2, linestyle='-.')
plt.plot(x, x+3, linestyle=':')

# %%
plt.plot(x, x+3,':') #можно очень сокращать, если есть такое сильно е желание

# %%
plt.plot(x,np.sin(x))
plt.xlim(-1,11)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %%
plt.plot(x,np.sin(x))
plt.xlim(10,0)
plt.ylim(1.5, -1.5)
# Out:
# (1.5, -1.5)

# %%
plt.plot(x, np.sin(x))
plt.axis([-1,11,-1.5,1.5]) # в одну строчку записываем се ограничения которые нужно
# Out:
# [-1, 11, -1.5, 1.5]

# %%
plt.plot(x, np.sin(x))
plt.axis('equal')
# Out:
# (-0.5, 10.5, -1.0999971452300779, 1.099999549246729)

# %%
plt.plot(x, np.sin(x))
plt.axis('equal') 
plt.title('A Sine Curve')
plt.xlabel('x')
plt.ylabel('sin(x)')
# Out:
# Text(0, 0.5, 'sin(x)')

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal') 
plt.legend()

# %%
#Another approach

# %%
ax = plt.axes()
ax.plot(x, np.sin(x), linestyle=':')
ax.set(xlim=(0,10), ylim=(-2,2), xlabel='x', ylabel='y',
      title="A simple Plot")
# Out:
# [(-2, 2),
#  Text(0, 0.5, 'y'),
#  (0, 10),
#  Text(0.5, 0, 'x'),
#  Text(0.5, 1.0, 'A simple Plot')]
