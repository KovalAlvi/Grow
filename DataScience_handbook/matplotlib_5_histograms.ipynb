# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn-whitegrid")
import numpy as np

# %%
data = np.random.randn(1000)
plt.hist(data)
# Out:
# (array([  3.,  18.,  63., 169., 271., 250., 151.,  57.,  17.,   1.]),
#  array([-3.40448026, -2.71942065, -2.03436103, -1.34930142, -0.66424181,
#          0.0208178 ,  0.70587742,  1.39093703,  2.07599664,  2.76105626,
#          3.44611587]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data, bins=42, alpha=0.5,
        histtype='stepfilled', color='steelblue',
        edgecolor='none')
# Out:
# (array([ 1.,  1.,  1.,  0.,  2.,  2.,  3.,  9.,  9.,  8., 15., 22., 23.,
#         27., 42., 49., 46., 64., 58., 74., 68., 61., 60., 65., 52., 43.,
#         29., 33., 37., 31., 20., 13.,  8.,  7., 10.,  3.,  2.,  1.,  0.,
#          0.,  0.,  1.]),
#  array([-3.40448026, -3.24137083, -3.0782614 , -2.91515196, -2.75204253,
#         -2.5889331 , -2.42582367, -2.26271424, -2.09960481, -1.93649537,
#         -1.77338594, -1.61027651, -1.44716708, -1.28405765, -1.12094822,
#         -0.95783878, -0.79472935, -0.63161992, -0.46851049, -0.30540106,
#         -0.14229163,  0.0208178 ,  0.18392724,  0.34703667,  0.5101461 ,
#          0.67325553,  0.83636496,  0.99947439,  1.16258383,  1.32569326,
#          1.48880269,  1.65191212,  1.81502155,  1.97813098,  2.14124042,
#          2.30434985,  2.46745928,  2.63056871,  2.79367814,  2.95678757,
#          3.11989701,  3.28300644,  3.44611587]),
#  <a list of 1 Patch objects>)

# %%
x1= np.random.normal(0, 0.8, 1000)
x2= np.random.normal(-2, 1, 1000)
x3= np.random.normal(3, 2, 1000)

kwargs = dict(bins=30, alpha=0.3, histtype='stepfilled')

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# (array([  2.,   0.,   0.,   3.,   5.,   9.,   6.,  18.,  31.,  36.,  42.,
#          64.,  75.,  73.,  95., 100.,  96.,  64.,  58.,  61.,  47.,  25.,
#          36.,  22.,  10.,  11.,   4.,   6.,   0.,   1.]),
#  array([-3.61128425, -3.18304492, -2.75480559, -2.32656626, -1.89832693,
#         -1.47008759, -1.04184826, -0.61360893, -0.1853696 ,  0.24286973,
#          0.67110907,  1.0993484 ,  1.52758773,  1.95582706,  2.38406639,
#          2.81230573,  3.24054506,  3.66878439,  4.09702372,  4.52526305,
#          4.95350238,  5.38174172,  5.80998105,  6.23822038,  6.66645971,
#          7.09469904,  7.52293838,  7.95117771,  8.37941704,  8.80765637,
#          9.2358957 ]),
#  <a list of 1 Patch objects>)

# %%
###ЧТобы посчитать но не выводить постоянно
counts, bin_edges = np.histogram(data, bins=5)
print(counts)
# Out:
# [ 21 232 521 208  18]

# %%
### Two dimensional histogram

# %%
mean = [0,1]
cov =  [[2,1],
        [1,1]]
x , y = np.random.multivariate_normal(mean, cov, 10000).T

# %%
plt.hist2d(x,y, bins=40, cmap='Blues')
cb = plt.colorbar()
cb.set_label('Counts in bin')

# %%
plt.hexbin(x, y, gridsize=20, cmap='Blues')
cb = plt.colorbar(label='count in bin')

# %%
x = np.linspace(0,10,100)
x.shape
# Out:
# (100,)

# %%
x[np.newaxis, : ].shape
# Out:
# (1, 100)

# %%
x[:, np.newaxis].shape
# Out:
# (100, 1)
